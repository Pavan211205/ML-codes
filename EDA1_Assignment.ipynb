# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('/content/Cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Display the first 5 rows of the dataset
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
#Display number of rows and cloumns
df.shape
# Out:
# (2126, 14)

# %%
# Data Cleaning and Preparation
# Check for missing values
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Handle missing values (if any)
# For simplicity, we'll drop rows with missing values
df = df.dropna()
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
#After dropping null values
df.shape
# Out:
# (2105, 14)

# %%
# Check for inconsistencies in data types
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# Detecting and treat outliers (using IQR method)
def detect_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    Lower_Limit = Q1 - (1.5 * IQR)
    Upper_Limit = Q3 + (1.5 * IQR)
    return column[(column < Lower_Limit ) | (column > Upper_Limit)]

outliers = {}
for col in df.select_dtypes(include=[np.number]).columns:
    outliers[col] = detect_outliers(df[col])

print("Outliers detected in each column are:")
for col, out in outliers.items():
    print(f"{col}: {len(out)} outliers")
# Out:
# Outliers detected in each column are:
# LB: 10 outliers
# AC: 39 outliers
# FM: 343 outliers
# UC: 13 outliers
# DL: 124 outliers
# DS: 120 outliers
# DP: 284 outliers
# ASTV: 10 outliers
# MSTV: 78 outliers
# ALTV: 317 outliers
# MLTV: 81 outliers
# Width: 10 outliers
# Tendency: 10 outliers
# NSP: 559 outliers

# %%
# Statistical Summary of the data
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.343598     0.003202     0.009963     0.004388     0.001892
# std      11.270154     0.004324     0.067870     0.003350     0.003348
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.000003     0.000175    46.996929     1.361006    10.353647
# std       0.000142     0.000840    18.847737     1.173164    21.282102
# ...

# %%
# Data Visualization
# Histograms for numerical variables
df.hist(bins=30, figsize=(15, 10))
plt.suptitle("Histograms for Numerical Variables")
plt.show()

# %%
# Boxplots for numerical variables
plt.figure(figsize=(15, 10))
sns.boxplot(data=df)
plt.title("Boxplots for Numerical Variables")
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Scatter plots for selected pairs of variables
sns.pairplot(df[['LB', 'AC', 'FM', 'UC', 'ASTV', 'MSTV']])
plt.suptitle("Pair Plots of Selected Variables", y=1.05)
plt.show()

# %%
# Pattern Recognition and Insights
# Identify correlations
corr_matrix
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.063830  0.018777 -0.166570 -0.126959 -0.005438
# AC       -0.063830  1.000000  0.010152  0.070135 -0.095491 -0.033623
# FM        0.018777  0.010152  1.000000 -0.052979  0.009830  0.029901
# UC       -0.166570  0.070135 -0.052979  1.000000  0.191864 -0.006937
# DL       -0.126959 -0.095491  0.009830  0.191864  1.000000  0.058625
# DS       -0.005438 -0.033623  0.029901 -0.006937  0.058625  1.000000
# DP       -0.047724 -0.084590  0.121284  0.070658  0.145425  0.004285
# ASTV      0.242625 -0.230487 -0.032783 -0.181133 -0.070792  0.008452
# MSTV     -0.170473  0.126752  0.017481  0.190011  0.410155  0.016163
# ALTV      0.210728 -0.273890 -0.012276 -0.227817 -0.186571 -0.004398
# MLTV     -0.003457 -0.106529 -0.006237 -0.049460 -0.165750  0.034349
# Width    -0.118425  0.238436  0.097213  0.107397  0.410031  0.040832
# Tendency  0.236864  0.032481 -0.018339 -0.066610 -0.023569 -0.015398
# ...

# %%
# Highlight strong correlations (absolute value > 0.5)
strong_correlations = corr_matrix[abs(corr_matrix) > 0.5]
print("Strong correlations (absolute value > 0.5) is:")
strong_correlations
# Out:
# Strong correlations (absolute value > 0.5) is:
#            LB   AC   FM   UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  Width  \
# LB        1.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# AC        NaN  1.0  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# FM        NaN  NaN  1.0  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# UC        NaN  NaN  NaN  1.0  NaN  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DL        NaN  NaN  NaN  NaN  1.0  NaN  NaN   NaN   NaN   NaN   NaN    NaN
# DS        NaN  NaN  NaN  NaN  NaN  1.0  NaN   NaN   NaN   NaN   NaN    NaN
# DP        NaN  NaN  NaN  NaN  NaN  NaN  1.0   NaN   NaN   NaN   NaN    NaN
# ASTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   1.0   NaN   NaN   NaN    NaN
# MSTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   1.0   NaN   NaN    NaN
# ALTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   1.0   NaN    NaN
# MLTV      NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   1.0    NaN
# ...

# %%
# Conclusion
print("Key Insights are:")
print("1. The dataset contains numerical variables related to fetal heart rate and uterine contractions.")
print("2. No missing values were found in the dataset.")
print("3. Outliers were detected in some columns, which may need further investigation.")
print("4. Strong correlations were observed between certain variables, such as LB and AC, which may indicate a relationship between baseline fetal heart rate and accelerations.")
print("5. Visualizations like histograms, boxplots, and correlation heatmaps provide a comprehensive understanding of the dataset's structure and relationships between variables.")
# Out:
# Key Insights are:
# 1. The dataset contains numerical variables related to fetal heart rate and uterine contractions.
# 2. No missing values were found in the dataset.
# 3. Outliers were detected in some columns, which may need further investigation.
# 4. Strong correlations were observed between certain variables, such as LB and AC, which may indicate a relationship between baseline fetal heart rate and accelerations.
# 5. Visualizations like histograms, boxplots, and correlation heatmaps provide a comprehensive understanding of the dataset's structure and relationships between variables.
