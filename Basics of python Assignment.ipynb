# %%
#EXERCISE1:
#Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

num=30
if num > 1:
  for i in range(2,num):
      if(num % i) == 0:
         print(num,"is not a prime number")
         break
  else:
      print(num,"is a prime number")
#if number less than or equal to 1
else:
  print(num,"is not a prime number")
# Out:
# 30 is not a prime number

# %%
#EXERCISE2:
#Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

import random
#Generating two random numbers between 1 to 100
num1 = random.randint(1, 100)
num2 = random.randint(1, 100)

#Calculate the actual product
actual_product = (num1 * num2)

#Asking the question to user and get the user answer
print(f"What is the product of {num1} and {num2}?")
user_answer = int(input("Enter your answer: "))

#Check the user answer is correct or not.
if (user_answer == actual_product):
    print("Answer is correct.")
else:
    print("Incorrect Answer. The correct answer is", actual_product)
# Out:
# What is the product of 56 and 58?
# Enter your answer: 285
# Incorrect Answer. The correct answer is 3248

# %%
#EXERCISE3:
#Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

#Even numbers were chosen because they are divisible by 2 and often used in computational examples for their uniform spacing.
for i in range(100,201):
  if i % 2 == 0:
    print(f"The square of {i} is {i**2}")
# Out:
# The square of 100 is 10000
# The square of 102 is 10404
# The square of 104 is 10816
# The square of 106 is 11236
# The square of 108 is 11664
# The square of 110 is 12100
# The square of 112 is 12544
# The square of 114 is 12996
# The square of 116 is 13456
# The square of 118 is 13924
# The square of 120 is 14400
# The square of 122 is 14884
# The square of 124 is 15376
# The square of 126 is 15876
# The square of 128 is 16384
# The square of 130 is 16900
# The square of 132 is 17424
# The square of 134 is 17956
# The square of 136 is 18496
# The square of 138 is 19044
# The square of 140 is 19600
# The square of 142 is 20164
# The square of 144 is 20736
# The square of 146 is 21316
# The square of 148 is 21904
# The square of 150 is 22500
# The square of 152 is 23104
# The square of 154 is 23716
# The square of 156 is 24336
# The square of 158 is 24964
# The square of 160 is 25600
# The square of 162 is 26244
# The square of 164 is 26896
# The square of 166 is 27556
# ...

# %%
#EXERCISE4:
#write a program to count the number of words in a given text.

input_text= 'I am learnig python and java'
word_count = len(input_text.split())
print('The number of words in the given text is',word_count)
# Out:
# The number of words in the given text is 6

# %%
#EXERCISE5:
#Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise.

def isPalindrome(str):
    return str==str[::-1]

str="madam"
ans= isPalindrome(str)

if ans:
    print("True")
else:
    print("False")
# Out:
# True
